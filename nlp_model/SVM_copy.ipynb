# %%
import pandas as pd
import nltk
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import svm
from sklearn.metrics import *
from collections import Counter
from pre_process import PreProcess
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import pandas as pd

data = pd.read_csv('./spam.csv')
print(data)
# Out:
#      Category                                            Message
# 0         ham  Go until jurong point, crazy.. Available only ...
# 1         ham                      Ok lar... Joking wif u oni...
# 2        spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         ham  U dun say so early hor... U c already then say...
# 4         ham  Nah I don't think he goes to usf, he lives aro...
# ...       ...                                                ...
# 5567     spam  This is the 2nd time we have tried 2 contact u...
# 5568      ham               Will ü b going to esplanade fr home?
# 5569      ham  Pity, * was in mood for that. So...any other s...
# 5570      ham  The guy did some bitching but I acted like i'd...
# 5571      ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
print(type(data["Message"]))
data["Message"] = PreProcess.preProcess(data["Message"])
print(data["Message"][0])
# Out:
# <class 'pandas.core.series.Series'>
# go until jurong point  crazy   available only in bugis n great world la e buffet    cine there got amore wat

# %%
print(data["Message"][0])
print(data["Message"].size)
for i in range(0, data["Message"].size):
  data["Message"][i] = PreProcess.standardize(data["Message"][i])
print(data["Message"][0])
# Out:
# go until jurong point  crazy   available only in bugis n great world la e buffet    cine there got amore wat
# 5572
# go jurong point crazy available bugis n great world la e buffet cine get amore wat

# %%
data["Label"] = 0
for i in range(0, data["Category"].size):
  data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20724\2858425811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Label"][i] = PreProcess.transformLabel(data["Category"][i])

# %%
X = data["Message"]
Y = data["Label"]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.8, test_size=0.2, random_state=0)
print(X_train, X_test, Y_train, Y_test)
# Out:
# 1114                          good movie ok leave hourish
# 3589    free give otherwise nalla adi entey nattil kittum
# 3095             emigrate something ok maybe bite hopeful
# 1012                            get home babe still awake
# 3320                                    kay since already
#                               ...
# 4931    hi sexychat girl wait text text great night ch...
# 3264                                  u gonna get deus ex
# 1653    ur chance win cash every wk txt action c www m...
# 2607                    r u sam p eachother meet go house
# 2732                  mm feel sleepy today shall get dear
# Name: Message, Length: 4457, dtype: object 4456    storm msg wen u lift phne u say hello u knw wt...
# 690           please call immediately urgent message wait
# 944     also sorta blow couple time recently id rather...
# 3768                            sir goodmorning free call
# 1189             come alive good correct good look figure
#                               ...
# 2906    ha know either clever simple thing pear day pe...
# 1270                       tee hee lecture cheery bye bye
# 3944    get call landline number ask come anna nagar g...
# 2124                                                error
# 253
# Name: Message, Length: 1115, dtype: object 1114    0
# 3589    0
# 3095    0
# 1012    0
# 3320    0
#        ..
# 4931    1
# 3264    0
# 1653    1
# 2607    0
# 2732    0
# Name: Label, Length: 4457, dtype: int64 4456    0
# 690     1
# 944     0
# 3768    0
# 1189    0
#        ..
# 2906    0
# 1270    0
# 3944    0
# 2124    1
# 253     0
# Name: Label, Length: 1115, dtype: int64

# %%
vocabulary = []
for text in X_train:
  for word in text.split():
    vocabulary.append(word)

dictionary = Counter(vocabulary)
vocabulary = []
for item in dictionary:
  if dictionary[item] >= 5:
    vocabulary.append(item)
print(len(vocabulary))
print(vocabulary)
# Out:
# 1320
# ['good', 'movie', 'ok', 'leave', 'free', 'give', 'otherwise', 'something', 'maybe', 'bite', 'get', 'home', 'babe', 'still', 'awake', 'since', 'already', 'workin', 'job', 'say', 'matter', 'mind', 'oh', 'yeah', 'diet', 'fly', 'sorry', 'thing', 'may', 'pub', 'late', 'ill', 'call', 'even', 'idea', 'dear', 'room', 'look', 'daddy', 'want', 'eat', 'night', 'long', 'chennai', 'surely', 'pick', 'u', 'da', 'car', 'park', 'okay', 'soon', 'best', 'yar', 'else', 'thk', 'sort', 'funny', 'yup', 'izzit', 'rain', 'co', 'e', 'mrt', 'c', 'outside', 'way', 'ur', 'pop', 'ask', 'bout', 'around', 'wen', 'girl', 'come', 'talk', 'g', 'x', 'cool', 'tyler', 'take', 'gonna', 'buy', 'drop', 'place', 'tonight', 'order', 'enough', 'work', 'time', 'village', 'near', 'house', 'would', 'wake', 'pls', 'family', 'hot', 'sun', 'strange', 'reason', 'go', 'invite', 'actually', 'wait', 'serious', 'whats', 'hill', 'hope', 'great', 'day', 'r', 'fine', 'busy', 'though', 'many', 'company', 'tell', 'honey', 'find', 'much', 'sell', 'nigeria', 'use', 'important', 'reply', 'monday', 'aight', 'lemme', 'know', 'today', 'plan', 'ready', 'moan', 'scream', 'right', 'make', 'sure', 'load', 'really', 'n', 'shoot', 'help', 'mobile', 'month', 'entitle', 'update', 'colour', 'camera', 'quite', 'liao', 'excuse', 'run', 'rite', 'hee', 'love', 'sit', 'wan', 'watch', 'wif', 'darren', 'mayb', 'xy', 'hello', 'news', 'week', 'im', 'thank', 'subscription', 'ringtone', 'uk', 'charge', 'please', 'confirm', 'yes', 'dunno', 'v', 'reach', 'inside', 'lor', 'gal', 'laugh', 'keep', 'pix', 'fantastic', 'chance', 'anything', 'need', 'big', 'life', 'lift', 'lose', 'live', 'think', 'first', 'person', 'die', 'usual', 'guy', 'last', 'anybody', 'let', 'throw', 'crazy', 'world', 'nokia', 'win', 'auction', 'part', 'send', 'hg', 'suite', 'land', 'row', 'w', 'almost', 'see', 'sec', 'bad', 'finger', 'train', 'play', 'min', 'haf', 'wat', 'lot', 'hospital', 'medical', 'safe', 'fuck', 'miss', 'money', 'towards', 'net', 'crave', 'happen', 'wow', 'mean', 'guess', 'men', 'change', 'search', 'location', 'cuz', 'page', 'customer', 'service', 'representative', 'pm', 'guarantee', 'cash', 'prize', 'tot', 'juz', 'yet', 'chikku', 'k', 'abt', 'tht', 'stop', 'irritate', 'forget', 'b', 'prepare', 'shall', 'morning', 'wine', 'sleep', 'well', 'wa', 'gee', 'thanx', 'ring', 'whole', 'hair', 'art', 'college', 'prob', 'email', 'account', 'number', 'probably', 'smile', 'tear', 'heart', 'like', 'mine', 'wil', 'care', 'oso', 'bore', 'happy', 'birthday', 'dream', 'true', 'lunch', 'aft', 'dat', 'str', 'orchard', 'baby', 'promise', 'treat', 'fat', 'press', 'also', 'feel', 'yesterday', 'til', 'convey', 'wish', 'nimya', 'hey', 'deal', 'balance', 'currently', 'pound', 'maximize', 'p', 'msg', 'cc', 'j', 'hl', 'th', 'campus', 'could', 'hour', 'two', 'oops', 'shower', 'stuff', 'quick', 'question', 'lol', 'saw', 'dollar', 'store', 'empty', 'without', 'eye', 'amp', 'frnds', 'touch', 'sweet', 'move', 'difficult', 'yo', 'stock', 'tomorrow', 'try', 'hows', 'friendship', 'read', 'forward', 'message', 'name', 'gud', 'evng', 'enjoy', 'mu', 'everyone', 'film', 'different', 'whatever', 'id', 'tv', 'excite', 'situation', 'egg', 'show', 'haha', 'hear', 'text', 'god', 'create', 'gap', 'sum', 'vry', 'special', 'fill', 'hold', 'hand', 'plz', 'dont', 'lt', 'gt', 'bus', 'sad', 'cover', 'face', 'kiss', 'project', 'pa', 'small', 'kid', 'secret', 'energy', 'ah', 'btw', 'wana', 'office', 'wonder', 'dude', 'always', 'party', 'drug', 'dey', 'darling', 'password', 'uncle', 'new', 'year', 'abiola', 'march', 'end', 'problem', 'never', 'complete', 'far', 'lady', 'boy', 'bt', 'didnt', 'decide', 'hit', 'save', 'hw', 'fast', 'drink', 'moral', 'story', 'ni', 'nice', 'immediately', 'lesson', 'blank', 'finish', 'fancy', 'wiv', 'tonite', 'break', 'hr', 'nite', 'mid', 'normal', 'couple', 'minute', 'dun', 'black', 'one', 'set', 'hella', 'gas', 'nature', 'little', 'okie', 'back', 'exactly', 'study', 'visit', 'apply', 'either', 'boytoy', 'geeee', 'bed', 'cuddle', 'boo', 'mom', 'xx', ...

# %%
for text in X_train:
  text = PreProcess.filter(text, vocabulary)

for text in X_test:
  text = PreProcess.filter(text, vocabulary)
 
print(X_train)
# Out:
# 1114                          good movie ok leave hourish
# 3589    free give otherwise nalla adi entey nattil kittum
# 3095             emigrate something ok maybe bite hopeful
# 1012                            get home babe still awake
# 3320                                    kay since already
#                               ...
# 4931    hi sexychat girl wait text text great night ch...
# 3264                                  u gonna get deus ex
# 1653    ur chance win cash every wk txt action c www m...
# 2607                    r u sam p eachother meet go house
# 2732                  mm feel sleepy today shall get dear
# Name: Message, Length: 4457, dtype: object

# %%
cv = CountVectorizer(ngram_range=(1, 3))
print(cv)
cv.fit_transform(X_train)
features_CV = cv.transform(X_train)
features_test_cv = cv.transform(X_test)

print(features_CV)
# Out:
# CountVectorizer(ngram_range=(1, 3))
#   (0, 18472)	1
#   (0, 18631)	1
#   (0, 18632)	1
#   (0, 21814)	1
#   (0, 25147)	1
#   (0, 25208)	1
#   (0, 30289)	1
#   (0, 30304)	1
#   (0, 30305)	1
#   (0, 33018)	1
#   (0, 33128)	1
#   (0, 33129)	1
#   (1, 441)	1
#   (1, 442)	1
#   (1, 443)	1
#   (1, 12970)	1
#   (1, 12971)	1
#   (1, 12972)	1
#   (1, 15366)	1
#   (1, 15439)	1
#   (1, 15441)	1
#   (1, 17441)	1
#   (1, 17554)	1
#   (1, 17555)	1
#   (1, 24145)	1
#   :	:
#   (4455, 21815)	1
#   (4455, 28601)	1
#   (4455, 28664)	1
#   (4455, 28665)	1
#   (4455, 39352)	1
#   (4455, 39353)	1
#   (4455, 39354)	1
#   (4456, 10272)	1
#   (4456, 14164)	1
#   (4456, 14247)	1
#   (4456, 14248)	1
#   (4456, 16533)	1
#   (4456, 16692)	1
#   (4456, 29551)	1
#   (4456, 29555)	1
#   (4456, 29556)	1
#   (4456, 40974)	1
#   (4456, 40987)	1
#   (4456, 40988)	1
#   (4456, 42043)	1
#   (4456, 42044)	1
#   (4456, 42045)	1
#   (4456, 47577)	1
#   (4456, 47674)	1
#   (4456, 47675)	1

# %%
model_svm = svm.SVC( C = 100, gamma = 0.01)
model_svm.fit(features_CV, Y_train)
# Out:
# SVC(C=100, gamma=0.01)

# %%
Y_preds_svm = model_svm.predict(features_test_cv)
print('SVM:')
print('Accuracy: ', accuracy_score(Y_test, Y_preds_svm)*100)
print('Precision: ', precision_score(Y_test, Y_preds_svm)*100)
print('Recall: ', recall_score(Y_test, Y_preds_svm)*100)
print('Confusion Matrix: ', confusion_matrix(Y_test, Y_preds_svm))
print('********************************************************')
# Out:
# SVM:
# Accuracy:  98.20627802690582
# Precision:  100.0
# Recall:  87.5
# Confusion Matrix:  [[955   0]
#  [ 20 140]]
# ********************************************************

# %%
from joblib import dump
dump(model_svm, 'model_svm')
# Out:
# ['model_svm']
